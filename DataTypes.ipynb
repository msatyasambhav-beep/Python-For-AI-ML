# %% [markdown]
# <a href="https://colab.research.google.com/github/msatyasambhav-beep/Python-For-AI-ML/blob/main/DataTypes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = 'mike'
type(name)
# Out:
# str

# %%
name = input('Enter your name: ')
print('Welcome', name)
# Out:
# Enter your name: Satya Sambhav Mohanty
# Welcome Satya Sambhav Mohanty

# %%
name
# Out:
# 'Satya Sambhav Mohanty'

# %%
type(name)
# Out:
# str

# %%
a = True
b = 'True'

# %%
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# TypeCasting

# %%
accuracy: 91.2%

# %%
acc = 91.2
print(acc)
type(acc)
# Out:
# 91.2
# float

# %%
int(acc)
# Out:
# 91

# %%
var = 2
type(var)
# Out:
# int

# %%
var1 = float(var)
type(var1)
# Out:
# float

# %%
var = 2.9
var_int = int(var)
print(var_int)
# Out:
# 2

# %%
var = 2
new_var = str(var)
type(new_var)
# Out:
# str

# %%
var_new = "2.5"
type(var_new)
# Out:
# str

# %%
int(float(var_new))
# Out:
# 2

# %%
#String to integer for float numners

# %%
string_var = "ABCDEFGH"

# %%
#String_var = 'HELLO'

#[H E L L O]
#H--> 0th index -5
#E--> 1st index -4
#L--> 2nd index -3
#L--> 3rd index -2
#O--> 4th index

# %%
String_var = 'HELLO'

# %%
String_var[1]
# Out:
# 'E'

# %%
Str1 = 'HELLO'

# %%
Str1
# Out:
# 'HELLO'

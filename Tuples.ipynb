# %% [markdown]
# <a href="https://colab.research.google.com/github/msatyasambhav-beep/Python-For-AI-ML/blob/main/Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tuples:
#
# -> Tuples are ordered sequnec of mixed data types
#
# -> tuples are written in comma separated eleements with parenthesis

# %%
t1 = (1,2,3,4)

# %%
type(t1)
# Out:
# tuple

# %%
t2 = [1,2,3,4,5]

# %%
type(t2)
# Out:
# list

# %%
t3 = 1,2,3,4,5

# %%
type(t3)
# Out:
# tuple

# %%
#a tuple can have a element having a tuple
t1 = ('hello',5,5.5,[2,3,4])

# %%
var = t1[3]
type(var)
# Out:
# list

# %%
nested_tuple = (1,2,3,(4,5))

# %%
len(nested_tuple)
# Out:
# 4

# %%
 # tuples can be defines in various way

# %%
t1 = 1,2,3,4,5
print(t1)
print(type(t1))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
t1 = 1.2
type(t1)
# Out:
# float

# %%
len(t1)

# %%
#single value tuple


t2 = 1,
print(t2)
# Out:
# (1,)

# %%
t3 = (1,)

# %%
#not a tuple
t4 = 1
t5 = (1)

# %%
type(t5)

# %% [markdown]
# Indexing in Tuple

# %%
t = ("Mumbai",10,"Python",100)

# %%
len(t)
# Out:
# 4

# %%
t[2:]
# Out:
# ('Python', 100)

# %%
#gives element at index location 0 , i.e !st eleemnt
print(t[0])

#gives element at index location 1 , i.e !st eleemnt
print(t[1])
# Out:
# Mumbai
# 10

# %% [markdown]
# Slicing

# %%
#Slicing first 2 elememnts
t = ("Mumbai",10,"Python",100)
t[0:2]
# Out:
# ('Mumbai', 10)

# %%
#slicing last 2 elemenst
t[2:]
# Out:
# ('Python', 100)

# %%
t[-2:]
# Out:
# ('Python', 100)

# %%
tup1 = (1,2,3,4,5)

# %%
tup2 =(7,8,9,10)

# %%
tup3 = tup1 + tup2
print(tup3)
# Out:
# (1, 2, 3, 4, 5, 7, 8, 9, 10)

# %%
# MAx min sum

# %%
max(tup1)
# Out:
# 5

# %%
min(tup1)
# Out:
# 1

# %%
sum(tup1)
# Out:
# 15

# %%
tuple1= (1,2,3,4,"hello","world",(1,2,3))

# %%
len(tuple1)
# Out:
# 7

# %%
tuple1[6][1]
# Out:
# 2

# %%
tuple1[-1][1]
# Out:
# 2

# %%
tuple1[-1][2]
# Out:
# 3

# %%
#Immutability

# %%
List_1 = ["bio","Chem","phy","Math"]

# %%
List_1[0] = "Comp Sc"
print(List_1)
# Out:
# ['Comp Sc', 'Chem', 'phy', 'Math']

# %%
tuple_1 = ("bio","Chem","phy","Math")

# %%
tuple_1[0] = "Comp Sc"
print(tuple_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2498/832329642.py in <cell line: 0>()
# ----> 1 tuple_1[0] = "Comp Sc"
#       2 print(tuple_1)
#
# TypeError: 'tuple' object does not support item assignment

# %%
t = ("Hello!","Welcome",5,10,"world","of","Analytics!")

# %%
t[-3]
# Out:
# 'world'

# %%
new_tuple = t[0:2] + ("to","the",) + t[-3:]

# %%
new_tuple
# Out:
# ('Hello!', 'Welcome', 'to', 'the', 'world', 'of', 'Analytics!')

# %%
#QUESTION
t = ("disco",12,4.5)
t[0][2]
# Out:
# 's'

# %% [markdown]
# Sorting a Tuple

# %%
t = (2,3,8,5,4,1)
new_var = sorted(t)
print(new_var)
print(type(new_var))
# Out:
# [1, 2, 3, 4, 5, 8]
# <class 'list'>

# %%
new_list=sorted(t)
new_list
# Out:
# [1, 2, 3, 4, 5, 8]

# %%
#Type-Casting
t2 = tuple(new_list)

# %%
t2
# Out:
# (1, 2, 3, 4, 5, 8)

# %%
x = sorted(t)
tuple(x)
# Out:
# (1, 2, 3, 4, 5, 8)

# %%
#QUestion1

t = (1,2,4,3)
#what will bne output of t[4]

# QUESTION2

#WHICH OF FOLLOWING DECLARATION CAN BE USED TO CREATE A PYTHON TUPLE
#MORE THAN 1 MAY BE TRUE
x = ('2')
x =1,2
x=((1,2,3),4,5)
x=(Hello,'2','3')

# %%
Ans 1 - index put pf bpund
Ans2 - 2 and 3

# %% [markdown]
# <a href="https://colab.research.google.com/github/msatyasambhav-beep/Python-For-AI-ML/blob/main/Arithmetic_Operation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Operations : Adiition,Substraction,Division,Floor division,Moduelus,Multiplication

# %%
a = 10
b = 2

# %%
a = 3
b = 4
a**b
# Out:
# 81

# %%
a/b
# Out:
# 0.75

# %%
a+b
# Out:
# 7

# %%
a-b
# Out:
# -1

# %%
a*b
# Out:
# 12

# %%
31//6
# Out:
# 5

# %%
a%b
# Out:
# 3

# %%
#BODMAS
print((4*5)-9+6/7)
# Out:
# 11.857142857142858

# %%
print(4%(1+9)*82 - 60//(7+2))
# Out:
# 322

# %%
60%7
# Out:
# 4

# %%
3**3
# Out:
# 27

# %%
3**4
# Out:
# 81

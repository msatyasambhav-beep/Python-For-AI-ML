# %% [markdown]
# <a href="https://colab.research.google.com/github/msatyasambhav-beep/Python-For-AI-ML/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Dict = {"name": "John","age":30}
type(Dict)
# Out:
# dict

# %% [markdown]
# Dictionary:
#
# -> Dictionary stored eleemnst as key value pair
#
# ->The key is like and index,its always unique and immutable
#
# ->The values are the objects that contain information
#
# ->Values are accessed using their keys
#
# ->Each key is followed by a value separated by a colon
#
# ->The values can be immutable,mutable and duplicates
#
# ->Each key and value pair is separated by a comma enclosed inside a curly brace\

# %%
#Creating a dictionary
d1 = {"India":"INR","USD":"USD","Hong Kong": "HKD"}

# %%
type(d1)
# Out:
# dict

# %%
len(d1)
# Out:
# 3

# %%
#Accessing value using key
d1["India"]
# Out:
# 'INR'

# %%
d1["Hong Kong"] = "HK$"
d1
# Out:
# {'India': 'INR', 'USD': 'USD', 'Hong Kong': 'HK$'}

# %%
d1["JApan"] = "YEN"

# %%
d1
# Out:
# {'India': 'INR', 'USD': 'USD', 'Hong Kong': 'HK$', 'JApan': 'YEN'}

# %%
sorted(d1)
# Out:
# ['Hong Kong', 'India', 'JApan', 'USD']

# %%
d1["India"] = "INR"

# %%
d1
# Out:
# {'India': 'INR', 'USD': 'USD', 'Hong Kong': 'HK$', 'JApan': 'YEN'}

# %%
d1["Hong Kong"]
# Out:
# 'HK$'

# %%
#values() method
d1.values()
# Out:
# dict_values(['INR', 'USD', 'HK$', 'YEN'])

# %%
#keys() method
d1.keys()
# Out:
# dict_keys(['India', 'USD', 'Hong Kong', 'JApan'])

# %%
#get method
d1.get('India')
# Out:
# 'INR'

# %%
#update() method
d1.update({"India":"Rs"})
d1
# Out:
# {'India': 'Rs', 'USD': 'USD', 'Hong Kong': 'HK$', 'JApan': 'YEN'}

# %%
d1["India"] = "INR"
d1
# Out:
# {'India': 'INR', 'USD': 'USD', 'Hong Kong': 'HK$', 'JApan': 'YEN'}

# %% [markdown]
# Practice codes:
#
# Q1 - write a code to fetch the profeesion of employee with employeeId - 104 from employee nput given in form of dict where key is id and value is name , age , profession
#
#
# sampleinput:
# Employee_data = {101:['Shiva',24,'Content Stratergist'],102:['Udit',25,'Content Stratergist'],103:['SOnam',28,'Sr Manager'],104:['Anasari',29,'Product Lead'],105:['Huzefa',32,'project Manager']}
#
# sample output :
# 'Product Lead

# %%
Employee_data = {101:['Shiva',24,'Content Stratergist'],102:['Udit',25,'Content Stratergist'],103:['SOnam',28,'Sr Manager'],104:['Anasari',29,'Product Lead'],105:['Huzefa',32,'project Manager']}

# %%
type(Employee_data)
# Out:
# dict

# %%
Employee_data
# Out:
# {101: ['Shiva', 24, 'Content Stratergist'],
#  102: ['Udit', 25, 'Content Stratergist'],
#  103: ['SOnam', 28, 'Sr Manager'],
#  104: ['Anasari', 29, 'Product Lead'],
#  105: ['Huzefa', 32, 'project Manager']}

# %%
type(Employee_data.get(104))
# Out:
# list

# %%
list_2 = Employee_data.get(104)

# %%
list_2[2]
# Out:
# 'Product Lead'

# %%
Employee_data[101][2]
# Out:
# 'Content Stratergist'

# %%
dict_1 = {'Python':40,'R':45}

# %%
del dict_1['R']

# %%
#Q2
dict_1
# Out:
# {'Python': 40}

# %%
#Q3
d = {'Python':40,'R':45}
print(list(d.keys()))
# Out:
# ['Python', 'R']

# %%
#4
get value of a key which is not a part of dictionary python doesnt hit an error it return NA

input:
{'Name': 'Monty','Profession':'Singer'}

sample output

NA

# %%
input_dict = {'Name': 'Monty','Profession':'Singer'}

# %%
input_dict["Label"] = "NA"

# %%
input_dict={'Name': 'Monty','Profession':'Singer'}

# %%
input_dict.keys()
# Out:
# dict_keys(['Name', 'Profession', 'Label'])

# %%
input_dict = {'Name': 'Monty','Profession':'Singer'}
if "Label" in input_dict.keys():
  print(input_dict["Label"])
else:
  print("NA")
# Out:
# NA

# %% [markdown]
# #Question 5
#
# *   List of vaues in a dictionary
#
# Creat a sorted list of all values from input
# return sorted values

# %%
input_dict = {'Jack Dorsey':'twitter','Tim Cook':'Apple','Jeff Bezos':'Amazon','Mukesh Ambani':'Reliance'}

# %%
sorted(input_dict.values())
# Out:
# ['Amazon', 'Apple', 'Reliance', 'twitter']

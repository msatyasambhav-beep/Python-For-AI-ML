# %% [markdown]
# <a href="https://colab.research.google.com/github/msatyasambhav-beep/Python-For-AI-ML/blob/main/DataStructures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# List
# -> List are ordered sequence of mixed data types
# ->list are written on comma separated elements withim square bracket

# %%
integer
float
string
combinational
lists-->nested lists

# %%
cust_info = ["Satyajit", 31, "Hong Kong", 12000,14000,"1GB"]

# %%
type(cust_info)
# Out:
# list

# %%
cust_info = ("Satyajit", 31, "Hong Kong", 12000,14000,"1GB")

# %%
type(cust_info)
# Out:
# tuple

# %%
list1 = ["India", 5, "Delhi"]

# %%
list1
# Out:
# ['India', 5, 'Delhi']

# %%
print(len(list1))
print(type(list1))
# Out:
# 3
# <class 'list'>

# %%
#nested list
list2 = ["india", "delhi",5,10,["Rajkot","Chennai"]]
len(list2)
# Out:
# 5

# %%
list2[-1][1]

# %%
list2[4][1]
# Out:
# 'Chennai'

# %%
list2[-1][-2]
# Out:
# 'Rajkot'

# %%
list2[4][0]
# Out:
# 'Rajkot'

# %%
list1 = [1,2,3,4]
list2= [5,6,7,8]
newList = list1 + list2

# %%
len(newList)
# Out:
# 8

# %%
newList
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
list3 = [1,2,3,4]
new_list = list3 + [5,6]
new_list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list3 = [1,2,3,4]
print(1 in list3)
# Out:
# True

# %%
list1 = ["maths","physics","chemistry","biology"]

# %%
list1[3]
# Out:
# 'biology'

# %%
list1[-1]
# Out:
# 'biology'

# %%
list1
# Out:
# ['maths', 'physics', 'chemistry', 'biology']

# %%
#Extend functions ---> it extends the ist
list1 = [1,2,3,4]
list1.extend([5,6])
len(list1)
# Out:
# 6

# %%
list1 = [1,2,3,4]
list1.append([5,6])
len(list1)
# Out:
# 5

# %%
list1
# Out:
# [1, 2, 3, 4, [5, 6]]

# %%
#del command
list1 = [1,2,3,4]
del list1[2]
list1
# Out:
# [1, 2, 4]

# %%
#pop
list1 = [11,22,33,44]
list1.pop(1)
list1
# Out:
# [11, 33, 44]

# %%
#Sorting
A = [9,5,2]
A.sort()
A
# Out:
# [2, 5, 9]

# %%
A.sort(reverse=True)
A
# Out:
# [9, 5, 2]

# %% [markdown]
# Difference between sort and sorted

# %%
A = ["Oranges","Strawberry","Mango"]
B = A.sort()
print(A)
print(B)
# Out:
# ['Mango', 'Oranges', 'Strawberry']
# None

# %%
A = ["Oranges","Strawberry","Mango"]
A.sort()

# %%
A = ["Oranges","Strawberry","Mango"]
B = sorted(A)
print(A)
print(B)
# Out:
# ['Oranges', 'Strawberry', 'Mango']
# ['Mango', 'Oranges', 'Strawberry']

# %%
#shallow copy

# %%
A = ["Oranges","Strawberry","Mango"]
B = A.pop()
print(B)
# Out:
# Mango

# %%
#Questions
# split the string ip str 'Kumar_Ravi_003'to persons second name , firtsdt name , and customer id . in this examle second name = "kumar, first name = "Ravi, customer code is 006

# %%
input_str = "Kumar_Ravi_003"

# %%
input_str
# Out:
# 'Kumar_Ravi_003'

# %%
str1 = input_str[0:5]
str1
# Out:
# 'Kumar'

# %%
str2 = input_str[6:10]
str2
# Out:
# 'Ravi'

# %%
str3 = input_str[-3:]
str3
# Out:
# '003'

# %%
print(str1)
print(str2)
print(str3)
# Out:
# Kumar
# Ravi
# 003

# %%
#equal to operator

# %%
a = [1,2,30]

# %%
type(a)
# Out:
# list

# %%
a
# Out:
# [1, 2, 30]

# %%
len(a)
# Out:
# 3

# %%
12 == 1
# Out:
# False

# %%
#Alert ->  '=' is an assignment operator , to assign valyue of an expression on right to a variable on left

# %%
10==5
# Out:
# False

# %%
#not equal to operator

# %%
10!=9
# Out:
# True

# %%
#less than operator
10<111
# Out:
# True

# %%
#greater than operator
10000>1
# Out:
# True

# %%
#less than equal to operator 
10 <= 12
# Out:
# True

# %%
#greater than equal to operator 
10 >= 2
# Out:
# True

# %%
#DECISION MAKING

# %%
# if-else block

# %%
age = 51

# %%
if age < 50:
    print("Young")
else:
    print("adult")
# Out:
# adult

# %%
age = 25

# %%
if age<20:
    print("Young")
elif age <30:
    print("Mid level")
else:
    print("Adult")
# Out:
# Mid level

# %%
if <>:
   something
else if <>:
    something else 
else if <>:
     something else
else:
    something else

# %%
#Write a progtam to check if variable x is odd or even

# %%
x = 5

# %%
if x %2 ==0:
    print("EVEN")
else:
    print("ODD")
# Out:
# ODD

# %%
#Write a program to accept age of visistor and allows him to PM party only if he is above 60 yeasrs or below 18 years of age

# %%
age = int(input("Enter age"))
if age>60 or age<18:
    print("Going to Party")
else:
    print("Not going")
# Out:
# Enter age 23
# Not going
